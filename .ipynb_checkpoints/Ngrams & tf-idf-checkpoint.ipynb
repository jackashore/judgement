# %% [markdown]
# <a href="https://colab.research.google.com/github/jackashore/judgement/blob/develop/Ngrams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import nltk
import pandas as pd
from bs4 import BeautifulSoup
from string import punctuation
from pymorphy2 import MorphAnalyzer
from nltk.collocations import *
from nltk.corpus import stopwords
from nltk.util import everygrams
from collections import Counter, OrderedDict
from sklearn.feature_extraction.text import TfidfVectorizer

stops = set(stopwords.words('russian'))
punct = punctuation+'«»—…“”*№–'
morph = MorphAnalyzer()

# %%
# nltk.download('stopwords')

# %%
df = pd.DataFrame()

# %%
# Функции скопированы из тетрадки про парсинг xml, со временем это превратится в прекрасного лебедя (импортируемый модуль)

meta_data = {'court': '', 'judge': '', 'prosecutor': '', 'secretary': '', 'accused': '', 'result': '', 'category': '', 
            'punishment_type': '', 'punishment_term': ''}

def parse_xml(path):   # парсим xml
    with open(path, 'r', encoding='utf-8')as f:
        soup = BeautifulSoup(f.read(), 'html.parser')
        
        meta_data['court'] = soup.court.string     # добавляем в метаданные то, что имеется в разметке
        meta_data['judge'] = soup.judge.string
        meta_data['result'] = soup.result.string
        meta_data['category'] = soup.category.string
        
        html = []
        for line in soup.body:
            line = line.replace('[', '')
            line = line.replace(']', '') 
            html.append(line)
        true_html = ' '.join(html)
                
        html_soup = BeautifulSoup(true_html, 'html.parser')
        return html_soup.get_text()
    
def get_parts(text):    # делим на части
    lines = [line for line in text.split('\n')]
    beg, end = 0, 0 
    for num, line in enumerate(lines):
        if 'установил' in line.lower() or 'у с т а н о в и л' in line.lower(): 
            beg = num + 1
        if 'приговорил' in line.lower() or 'п р и г о в о р и л' in line.lower() or 'постановил'\
         in line.lower() or 'п о с т а н о в и л' in line.lower():
            end = num + 1
        
        if beg and end:
            beginning = [stroka.strip() for stroka in lines[:beg]]
            main_part = [stroka.strip() for stroka in lines[beg:end]]
            ending = [stroka.strip() for stroka in lines[end:]]
            return [' '.join(main_part), ' '.join(beginning), ' '.join(ending)]
        
def process_xml(path):
    return get_parts(parse_xml(path))[0]

# %%
main_path = r'C:\Users\a.reshetniko\Documents\trash\judgment\judgement\belinskij-rajonnyj-sud-penzenskaya-oblast-263'
raw_texts = []
for items in os.walk(main_path):
    for file in items[2]:
        file_path = os.path.join(items[0], file)
        raw_texts.append(process_xml(file_path))

df['raw_main_parts'] = raw_texts

# %% [markdown]
# * Прикрутить Верин токенизатор
# * Подумать о лемматизаторе

# %%
def normalize(text):
    words = [word.strip(punct) for word in text.lower().split()] 
    # words = [word for word in words if word and word not in stops]
    words = [morph.parse(word)[0].normal_form for word in words if word]

    return words

# %%
df['norm_main_parts'] = df['raw_main_parts'].apply(normalize)

# %%
df.head()
# Out:
#                                       raw_main_parts  \
# 0   Стульников С.В. совершил кражу, т.е. тайное х...
# 1   Крутилин С.В., являясь лицом, управляющим авт...
# 2   Видюлин П.А. обвиняется в совершении неправом...
# 3   Кузнецов М.Ю. совершил нарушение лицом, управ...
# 4   Кочетков Д.Г. совершил нарушение лицом, управ...
#
#                                      norm_main_parts
# 0  [стульник, с.в, совершить, кража, т.е, тайный,...
# 1  [крутилина, с.в, являться, лицо, управлять, ав...
# 2  [видюлина, п.а, обвиняться, в, совершение, неп...
# 3  [кузнецов, м.ю, совершить, нарушение, лицо, уп...
# 4  [кочетков, д.г, совершить, нарушение, лицо, уп...

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (115, 2)

# %%
all_t = []
for text in df.norm_main_parts:
    all_t.extend(text)

# %%
colloc_1000 = []
for col in Counter(list(everygrams(all_t, min_len=3, max_len=10))).most_common(1000):
    print(col)
    colloc_1000.append(' '.join(col[0]))
# Out:
# (('в', 'судебный', 'заседание'), 559)
# (('без', 'проведение', 'судебный'), 228)
# (('проведение', 'судебный', 'разбирательство'), 228)
# (('без', 'проведение', 'судебный', 'разбирательство'), 228)
# (('приговор', 'без', 'проведение'), 227)
# (('приговор', 'без', 'проведение', 'судебный'), 227)
# (('приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 227)
# (('хищение', 'чужое', 'имущество'), 225)
# (('правило', 'дорожный', 'движение'), 202)
# (('проезжий', 'часть', 'автодорога'), 194)
# (('постановление', 'приговор', 'без'), 193)
# (('постановление', 'приговор', 'без', 'проведение'), 193)
# (('постановление', 'приговор', 'без', 'проведение', 'судебный'), 193)
# (('постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 193)
# (('наказание', 'в', 'вид'), 172)
# (('в', 'сумма', 'рубль'), 170)
# (('тяжкий', 'вред', 'здоровье'), 166)
# (('тайный', 'хищение', 'чужое'), 155)
# (('тайный', 'хищение', 'чужое', 'имущество'), 155)
# (('сторона', 'проезжий', 'часть'), 150)
# (('судебный', 'заседание', 'показать'), 142)
# (('в', 'судебный', 'заседание', 'показать'), 142)
# (('медицинский', 'критерий', 'определение'), 140)
# (('тяжесть', 'вред', 'причинить'), 140)
# (('вред', 'причинить', 'здоровье'), 140)
# (('причинить', 'здоровье', 'человек'), 140)
# (('тяжесть', 'вред', 'причинить', 'здоровье'), 140)
# (('вред', 'причинить', 'здоровье', 'человек'), 140)
# (('тяжесть', 'вред', 'причинить', 'здоровье', 'человек'), 140)
# (('пояснить', 'в', 'судебный'), 139)
# (('в', 'связь', 'с'), 138)
# (('общественный', 'опасность', 'совершенный'), 138)
# (('степень', 'общественный', 'опасность'), 137)
# (('заседание', 'показать', 'что'), 137)
# (('пояснить', 'в', 'судебный', 'заседание'), 137)
# (('судебный', 'заседание', 'показать', 'что'), 137)
# (('в', 'судебный', 'заседание', 'показать', 'что'), 137)
# (('судебный', 'заседание', 'следующий'), 135)
# (('в', 'судебный', 'заседание', 'следующий'), 135)
# (('пояснить', 'в', 'судебный', 'заседание', 'следующий'), 135)
# (('критерий', 'определение', 'тяжесть'), 133)
# (('определение', 'тяжесть', 'вред'), 133)
# (('медицинский', 'критерий', 'определение', 'тяжесть'), 133)
# (('критерий', 'определение', 'тяжесть', 'вред'), 133)
# (('определение', 'тяжесть', 'вред', 'причинить'), 133)
# (('степень', 'общественный', 'опасность', 'совершенный'), 133)
# (('медицинский', 'критерий', 'определение', 'тяжесть', 'вред'), 133)
# (('критерий', 'определение', 'тяжесть', 'вред', 'причинить'), 133)
# (('определение', 'тяжесть', 'вред', 'причинить', 'здоровье'), 133)
# (('медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить'), 133)
# (('критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье'), 133)
# (('определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек'), 133)
# (('медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье'), 133)
# (('критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек'), 133)
# (('медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек'), 133)
# (('при', 'движение', 'к'), 128)
# (('в', 'соответствие', 'с'), 125)
# (('осмотр', 'место', 'происшествие'), 122)
# (('о', 'тот', 'что'), 122)
# (('в', 'вид', 'лишение'), 121)
# (('дорожный', 'движение', 'рф'), 120)
# (('правило', 'дорожный', 'движение', 'рф'), 120)
# (('при', 'следующий', 'обстоятельство'), 118)
# (('автодорога', 'при', 'движение'), 117)
# (('правый', 'сторона', 'проезжий'), 115)
# (('правый', 'сторона', 'проезжий', 'часть'), 115)
# (('особо', 'крупный', 'размер'), 114)
# (('сторона', 'проезжий', 'часть', 'автодорога'), 112)
# (('автодорога', 'при', 'движение', 'к'), 110)
# (('характер', 'и', 'степень'), 109)
# (('и', 'размер', 'наказание'), 108)
# (('из', 'корыстный', 'побуждение'), 106)
# (('наказание', 'в', 'вид', 'лишение'), 106)
# (('вид', 'и', 'размер'), 104)
# (('вид', 'и', 'размер', 'наказание'), 104)
# (('принимать', 'в', 'внимание'), 101)
# (('ст.158', 'ук', 'рф'), 101)
# (('вид', 'лишение', 'свобода'), 100)
# (('в', 'вид', 'лишение', 'свобода'), 100)
# (('при', 'определение', 'вид'), 99)
# (('на', 'место', 'дтп'), 99)
# (('по', 'предварительный', 'сговор'), 99)
# (('определение', 'вид', 'и'), 98)
# (('по', 'дело', 'не'), 98)
# (('при', 'определение', 'вид', 'и'), 98)
# (('определение', 'вид', 'и', 'размер'), 98)
# (('при', 'определение', 'вид', 'и', 'размер'), 98)
# (('определение', 'вид', 'и', 'размер', 'наказание'), 98)
# (('при', 'определение', 'вид', 'и', 'размер', 'наказание'), 98)
# (('ук', 'рф', 'и'), 97)
# (('группа', 'лицо', 'по'), 97)
# (('лицо', 'по', 'предварительный'), 97)
# (('группа', 'лицо', 'по', 'предварительный'), 97)
# (('лицо', 'по', 'предварительный', 'сговор'), 97)
# (('группа', 'лицо', 'по', 'предварительный', 'сговор'), 97)
# (('дело', 'не', 'установить'), 96)
# (('по', 'дело', 'не', 'установить'), 96)
# (('ук', 'рф', 'как'), 90)
# (('и', 'степень', 'общественный'), 88)
# (('характер', 'и', 'степень', 'общественный'), 88)
# (('и', 'степень', 'общественный', 'опасность'), 88)
# (('характер', 'и', 'степень', 'общественный', 'опасность'), 88)
# (('для', 'жизнь', 'человек'), 87)
# (('сбыт', 'наркотический', 'средство'), 86)
# (('в', 'совершение', 'инкриминировать'), 85)
# (('наказание', 'в', 'вид', 'лишение', 'свобода'), 85)
# (('протокол', 'осмотр', 'место'), 84)
# (('и', 'степень', 'общественный', 'опасность', 'совершенный'), 84)
# (('характер', 'и', 'степень', 'общественный', 'опасность', 'совершенный'), 84)
# (('денежный', 'средство', 'в'), 83)
# (('протокол', 'осмотр', 'место', 'происшествие'), 82)
# (('правый', 'сторона', 'проезжий', 'часть', 'автодорога'), 82)
# (('отягчать', 'наказание', 'подсудимый'), 81)
# (('в', 'полный', 'объём'), 80)
# (('в', 'предел', 'санкция'), 80)
# (('совершенный', 'имя', 'преступление'), 79)
# (('по', 'направление', 'к'), 79)
# (('упк', 'рф', 'суд'), 78)
# (('наркотический', 'средство', 'в'), 78)
# (('суд', 'принимать', 'в'), 77)
# (('суд', 'принимать', 'в', 'внимание'), 77)
# (('незаконный', 'проникновение', 'в'), 76)
# (('а', 'так', 'же'), 76)
# (('кража', 'то', 'есть'), 76)
# (('наркотический', 'средство', 'марихуана'), 76)
# (('158', 'ук', 'рф'), 75)
# (('правильно', 'квалифицировать', 'по'), 75)
# (('здоровье', 'человек', 'приказ'), 75)
# (('судебный', 'разбирательство', 'по'), 75)
# (('размер', 'наказание', 'подсудимый'), 75)
# (('вред', 'здоровье', 'по'), 75)
# (('причинить', 'здоровье', 'человек', 'приказ'), 75)
# (('и', 'размер', 'наказание', 'подсудимый'), 75)
# (('вред', 'причинить', 'здоровье', 'человек', 'приказ'), 75)
# (('вид', 'и', 'размер', 'наказание', 'подсудимый'), 75)
# (('тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ'), 75)
# (('определение', 'вид', 'и', 'размер', 'наказание', 'подсудимый'), 75)
# (('при', 'определение', 'вид', 'и', 'размер', 'наказание', 'подсудимый'), 75)
# (('ст', '158', 'ук'), 74)
# (('опасность', 'совершенный', 'преступление'), 74)
# (('здоровье', 'по', 'признак'), 74)
# (('ст', '158', 'ук', 'рф'), 74)
# (('общественный', 'опасность', 'совершенный', 'преступление'), 74)
# (('вред', 'здоровье', 'по', 'признак'), 74)
# (('степень', 'общественный', 'опасность', 'совершенный', 'преступление'), 74)
# (('с', 'незаконный', 'проникновение'), 73)
# (('человек', 'приказ', 'минздравсоцразвития'), 73)
# (('приказ', 'минздравсоцразвития', 'россия'), 73)
# (('минздравсоцразвития', 'россия', 'от'), 73)
# (('иметь', 'умысел', 'на'), 73)
# (('в', 'внимание', 'характер'), 73)
# (('внимание', 'характер', 'и'), 73)
# (('обстоятельство', 'смягчающий', 'наказание'), 73)
# (('316', 'упк', 'рф'), 73)
# (('обстоятельство', 'смягчающий', 'и'), 73)
# (('смягчающий', 'и', 'отягчать'), 73)
# (('с', 'незаконный', 'проникновение', 'в'), 73)
# (('здоровье', 'человек', 'приказ', 'минздравсоцразвития'), 73)
# (('человек', 'приказ', 'минздравсоцразвития', 'россия'), 73)
# (('приказ', 'минздравсоцразвития', 'россия', 'от'), 73)
# (('принимать', 'в', 'внимание', 'характер'), 73)
# (('в', 'внимание', 'характер', 'и'), 73)
# (('внимание', 'характер', 'и', 'степень'), 73)
# (('обстоятельство', 'смягчающий', 'и', 'отягчать'), 73)
# (('причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития'), 73)
# (('здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия'), 73)
# (('человек', 'приказ', 'минздравсоцразвития', 'россия', 'от'), 73)
# (('суд', 'принимать', 'в', 'внимание', 'характер'), 73)
# (('принимать', 'в', 'внимание', 'характер', 'и'), 73)
# (('в', 'внимание', 'характер', 'и', 'степень'), 73)
# (('внимание', 'характер', 'и', 'степень', 'общественный'), 73)
# (('вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития'), 73)
# (('причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия'), 73)
# (('здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от'), 73)
# (('суд', 'принимать', 'в', 'внимание', 'характер', 'и'), 73)
# (('принимать', 'в', 'внимание', 'характер', 'и', 'степень'), 73)
# (('в', 'внимание', 'характер', 'и', 'степень', 'общественный'), 73)
# (('внимание', 'характер', 'и', 'степень', 'общественный', 'опасность'), 73)
# (('определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ'), 73)
# (('тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития'), 73)
# (('вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия'), 73)
# (('причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от'), 73)
# (('суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень'), 73)
# (('принимать', 'в', 'внимание', 'характер', 'и', 'степень', 'общественный'), 73)
# (('в', 'внимание', 'характер', 'и', 'степень', 'общественный', 'опасность'), 73)
# (('внимание', 'характер', 'и', 'степень', 'общественный', 'опасность', 'совершенный'), 73)
# (('критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ'), 73)
# (('определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития'), 73)
# (('тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия'), 73)
# (('вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от'), 73)
# (('суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень', 'общественный'), 73)
# (('принимать', 'в', 'внимание', 'характер', 'и', 'степень', 'общественный', 'опасность'), 73)
# (('в', 'внимание', 'характер', 'и', 'степень', 'общественный', 'опасность', 'совершенный'), 73)
# (('медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ'), 73)
# (('критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития'), 73)
# (('определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия'), 73)
# (('тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от'), 73)
# (('суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень', 'общественный', 'опасность'), 73)
# (('принимать', 'в', 'внимание', 'характер', 'и', 'степень', 'общественный', 'опасность', 'совершенный'), 73)
# (('медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития'), 73)
# (('критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия'), 73)
# (('определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от'), 73)
# (('суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень', 'общественный', 'опасность', 'совершенный'), 73)
# (('вина', 'в', 'совершение'), 72)
# (('ук', 'рф', 'суд'), 71)
# (('как', 'тяжкий', 'вред'), 71)
# (('то', 'есть', 'тайный'), 71)
# (('есть', 'тайный', 'хищение'), 71)
# (('как', 'тяжкий', 'вред', 'здоровье'), 71)
# (('кража', 'то', 'есть', 'тайный'), 71)
# (('то', 'есть', 'тайный', 'хищение'), 71)
# (('кража', 'то', 'есть', 'тайный', 'хищение'), 71)
# (('по', 'место', 'жительство'), 70)
# (('наказание', 'подсудимый', 'суд'), 70)
# (('ч.2', 'ст.158', 'ук'), 70)
# (('приходить', 'к', 'вывод'), 70)
# (('от', '24', 'апрель'), 70)
# (('24', 'апрель', '2008'), 70)
# (('ч.2', 'ст.158', 'ук', 'рф'), 70)
# (('от', '24', 'апрель', '2008'), 70)
# (('есть', 'тайный', 'хищение', 'чужое'), 70)
# (('то', 'есть', 'тайный', 'хищение', 'чужое'), 70)
# (('есть', 'тайный', 'хищение', 'чужое', 'имущество'), 70)
# (('кража', 'то', 'есть', 'тайный', 'хищение', 'чужое'), 70)
# (('то', 'есть', 'тайный', 'хищение', 'чужое', 'имущество'), 70)
# (('кража', 'то', 'есть', 'тайный', 'хищение', 'чужое', 'имущество'), 70)
# (('апрель', '2008', 'год'), 69)
# (('полоса', 'встречный', 'движение'), 69)
# (('размер', 'наказание', 'подсудимый', 'суд'), 69)
# (('24', 'апрель', '2008', 'год'), 69)
# (('и', 'размер', 'наказание', 'подсудимый', 'суд'), 69)
# (('от', '24', 'апрель', '2008', 'год'), 69)
# (('вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд'), 69)
# (('определение', 'вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд'), 69)
# (('при', 'определение', 'вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд'), 69)
# (('ук', 'рф', 'в'), 68)
# (('2008', 'год', '194н'), 68)
# (('в', 'ход', 'предварительный'), 68)
# (('судебный', 'разбирательство', 'в'), 68)
# (('мнение', 'государственный', 'обвинитель'), 68)
# (('средство', 'в', 'сумма'), 68)
# (('тяжкий', 'вред', 'здоровье', 'по'), 68)
# (('апрель', '2008', 'год', '194н'), 68)
# (('денежный', 'средство', 'в', 'сумма'), 68)
# (('24', 'апрель', '2008', 'год', '194н'), 68)
# (('от', '24', 'апрель', '2008', 'год', '194н'), 68)
# (('тяжкий', 'вред', 'здоровье', 'по', 'признак'), 67)
# (('по', 'правый', 'сторона'), 66)
# (('опасность', 'для', 'жизнь'), 66)
# (('данный', 'ходатайство', 'заявить'), 66)
# (('добровольно', 'и', 'после'), 66)
# (('консультация', 'с', 'защитник'), 66)
# (('последствие', 'постановление', 'приговор'), 66)
# (('на', 'правый', 'сторона'), 66)
# (('на', 'основание', 'изложить'), 66)
# (('последствие', 'постановление', 'приговор', 'без'), 66)
# (('последствие', 'постановление', 'приговор', 'без', 'проведение'), 66)
# (('последствие', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 66)
# (('последствие', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 66)
# (('чужое', 'имущество', 'с'), 65)
# (('в', 'результат', 'что'), 65)
# (('суд', 'не', 'находить'), 65)
# (('движение', 'к', 'адрес'), 65)
# (('хищение', 'чужое', 'имущество', 'с'), 65)
# (('по', 'свой', 'усмотрение'), 64)
# (('состояние', 'алкогольный', 'опьянение'), 64)
# (('по', 'признак', 'опасность'), 64)
# (('признак', 'опасность', 'для'), 64)
# (('согласие', 'с', 'предъявить'), 64)
# (('доказательство', 'собранный', 'по'), 64)
# (('а', 'также', 'мнение'), 64)
# (('россия', 'от', '24'), 64)
# (('на', 'полоса', 'встречный'), 64)
# (('по', 'признак', 'опасность', 'для'), 64)
# (('признак', 'опасность', 'для', 'жизнь'), 64)
# (('минздравсоцразвития', 'россия', 'от', '24'), 64)
# (('россия', 'от', '24', 'апрель'), 64)
# (('на', 'полоса', 'встречный', 'движение'), 64)
# (('по', 'признак', 'опасность', 'для', 'жизнь'), 64)
# (('приказ', 'минздравсоцразвития', 'россия', 'от', '24'), 64)
# (('минздравсоцразвития', 'россия', 'от', '24', 'апрель'), 64)
# (('россия', 'от', '24', 'апрель', '2008'), 64)
# (('человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24'), 64)
# (('приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель'), 64)
# (('минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008'), 64)
# (('россия', 'от', '24', 'апрель', '2008', 'год'), 64)
# (('здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24'), 64)
# (('человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель'), 64)
# (('приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008'), 64)
# (('минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год'), 64)
# (('россия', 'от', '24', 'апрель', '2008', 'год', '194н'), 64)
# (('причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24'), 64)
# (('здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель'), 64)
# (('человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008'), 64)
# (('приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год'), 64)
# (('минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год', '194н'), 64)
# (('вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24'), 64)
# (('причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель'), 64)
# (('здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008'), 64)
# (('человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год'), 64)
# (('приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год', '194н'), 64)
# (('тяжесть', 'вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24'), 64)
# (('вред', 'причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель'), 64)
# (('причинить', 'здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008'), 64)
# (('здоровье', 'человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год'), 64)
# (('человек', 'приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год', '194н'), 64)
# (('признать', 'в', 'полный'), 63)
# (('в', 'состояние', 'алкогольный'), 63)
# (('о', 'постановление', 'приговор'), 63)
# (('подтверждаться', 'доказательство', 'собранный'), 63)
# (('на', 'общий', 'сумма'), 63)
# (('вид', 'наказание', 'предусмотренный'), 63)
# (('признать', 'в', 'полный', 'объём'), 63)
# (('в', 'состояние', 'алкогольный', 'опьянение'), 63)
# (('о', 'постановление', 'приговор', 'без'), 63)
# (('подтверждаться', 'доказательство', 'собранный', 'по'), 63)
# (('о', 'постановление', 'приговор', 'без', 'проведение'), 63)
# (('о', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 63)
# (('о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 63)
# (('ходатайствовать', 'о', 'постановление'), 62)
# (('разбирательство', 'по', 'дело'), 62)
# (('по', 'дело', 'заявить'), 62)
# (('дело', 'заявить', 'что'), 62)
# (('заявить', 'что', 'данный'), 62)
# (('что', 'данный', 'ходатайство'), 62)
# (('и', 'после', 'консультация'), 62)
# (('после', 'консультация', 'с'), 62)
# (('с', 'защитник', 'а'), 62)
# (('о', 'мера', 'наказание'), 62)
# (('ходатайствовать', 'о', 'постановление', 'приговор'), 62)
# (('проведение', 'судебный', 'разбирательство', 'по'), 62)
# (('судебный', 'разбирательство', 'по', 'дело'), 62)
# (('разбирательство', 'по', 'дело', 'заявить'), 62)
# (('по', 'дело', 'заявить', 'что'), 62)
# (('дело', 'заявить', 'что', 'данный'), 62)
# (('заявить', 'что', 'данный', 'ходатайство'), 62)
# (('что', 'данный', 'ходатайство', 'заявить'), 62)
# (('добровольно', 'и', 'после', 'консультация'), 62)
# (('и', 'после', 'консультация', 'с'), 62)
# (('после', 'консультация', 'с', 'защитник'), 62)
# (('консультация', 'с', 'защитник', 'а'), 62)
# (('проведение', 'судебный', 'разбирательство', 'в'), 62)
# (('ходатайствовать', 'о', 'постановление', 'приговор', 'без'), 62)
# (('без', 'проведение', 'судебный', 'разбирательство', 'по'), 62)
# (('проведение', 'судебный', 'разбирательство', 'по', 'дело'), 62)
# (('судебный', 'разбирательство', 'по', 'дело', 'заявить'), 62)
# (('разбирательство', 'по', 'дело', 'заявить', 'что'), 62)
# (('по', 'дело', 'заявить', 'что', 'данный'), 62)
# (('дело', 'заявить', 'что', 'данный', 'ходатайство'), 62)
# (('заявить', 'что', 'данный', 'ходатайство', 'заявить'), 62)
# (('добровольно', 'и', 'после', 'консультация', 'с'), 62)
# (('и', 'после', 'консультация', 'с', 'защитник'), 62)
# (('после', 'консультация', 'с', 'защитник', 'а'), 62)
# (('как', 'тяжкий', 'вред', 'здоровье', 'по'), 62)
# (('без', 'проведение', 'судебный', 'разбирательство', 'в'), 62)
# (('ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение'), 62)
# (('приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по'), 62)
# (('без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело'), 62)
# (('проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить'), 62)
# (('судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что'), 62)
# (('разбирательство', 'по', 'дело', 'заявить', 'что', 'данный'), 62)
# (('по', 'дело', 'заявить', 'что', 'данный', 'ходатайство'), 62)
# (('дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить'), 62)
# (('добровольно', 'и', 'после', 'консультация', 'с', 'защитник'), 62)
# (('и', 'после', 'консультация', 'с', 'защитник', 'а'), 62)
# (('как', 'тяжкий', 'вред', 'здоровье', 'по', 'признак'), 62)
# (('ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 62)
# (('постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по'), 62)
# (('приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело'), 62)
# (('без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить'), 62)
# (('проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что'), 62)
# (('судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный'), 62)
# (('разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство'), 62)
# (('по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить'), 62)
# (('добровольно', 'и', 'после', 'консультация', 'с', 'защитник', 'а'), 62)
# (('ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 62)
# (('о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по'), 62)
# (('постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело'), 62)
# (('приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить'), 62)
# (('без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что'), 62)
# (('проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный'), 62)
# (('судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство'), 62)
# (('разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить'), 62)
# (('ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по'), 62)
# (('о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело'), 62)
# (('постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить'), 62)
# (('приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что'), 62)
# (('без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный'), 62)
# (('проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство'), 62)
# (('судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить'), 62)
# (('ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело'), 62)
# (('о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить'), 62)
# (('постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что'), 62)
# (('приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный'), 62)
# (('без', 'проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство'), 62)
# (('проведение', 'судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить'), 62)
# (('выразить', 'свой', 'согласие'), 61)
# (('свой', 'согласие', 'с'), 61)
# (('и', 'ходатайствовать', 'о'), 61)
# (('часть', 'автодорога', 'при'), 61)
# (('по', 'адрес', 'адрес'), 61)
# (('выразить', 'свой', 'согласие', 'с'), 61)
# (('свой', 'согласие', 'с', 'предъявить'), 61)
# (('и', 'ходатайствовать', 'о', 'постановление'), 61)
# (('проезжий', 'часть', 'автодорога', 'при'), 61)
# (('часть', 'автодорога', 'при', 'движение'), 61)
# (('при', 'движение', 'к', 'адрес'), 61)
# (('выразить', 'свой', 'согласие', 'с', 'предъявить'), 61)
# (('и', 'ходатайствовать', 'о', 'постановление', 'приговор'), 61)
# (('проезжий', 'часть', 'автодорога', 'при', 'движение'), 61)
# (('и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без'), 61)
# (('приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'в'), 61)
# (('и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение'), 61)
# (('и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 61)
# (('и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 61)
# (('и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство', 'по'), 61)
# (('подсудимый', 'суд', 'принимать'), 60)
# (('основание', 'изложить', 'и'), 60)
# (('изложить', 'и', 'руководствоваться'), 60)
# (('в', 'особо', 'крупный'), 60)
# (('опасность', 'для', 'жизнь', 'человек'), 60)
# (('основание', 'изложить', 'и', 'руководствоваться'), 60)
# (('в', 'особо', 'крупный', 'размер'), 60)
# (('ук', 'рф', 'поскольку'), 59)
# (('сведение', 'о', 'личность'), 59)
# (('сторона', 'защита', 'о'), 59)
# (('назначить', 'наказание', 'на'), 59)
# (('опасный', 'для', 'жизнь'), 59)
# (('свой', 'преступный', 'умысел'), 59)
# (('по', 'правый', 'сторона', 'проезжий'), 59)
# (('здоровье', 'по', 'признак', 'опасность'), 59)
# (('наказание', 'подсудимый', 'суд', 'принимать'), 59)
# (('подсудимый', 'суд', 'принимать', 'в'), 59)
# (('на', 'основание', 'изложить', 'и'), 59)
# (('по', 'правый', 'сторона', 'проезжий', 'часть'), 59)
# (('признак', 'опасность', 'для', 'жизнь', 'человек'), 59)
# (('вред', 'здоровье', 'по', 'признак', 'опасность'), 59)
# (('здоровье', 'по', 'признак', 'опасность', 'для'), 59)
# (('часть', 'автодорога', 'при', 'движение', 'к'), 59)
# (('размер', 'наказание', 'подсудимый', 'суд', 'принимать'), 59)
# (('наказание', 'подсудимый', 'суд', 'принимать', 'в'), 59)
# (('подсудимый', 'суд', 'принимать', 'в', 'внимание'), 59)
# (('на', 'основание', 'изложить', 'и', 'руководствоваться'), 59)
# (('по', 'признак', 'опасность', 'для', 'жизнь', 'человек'), 59)
# (('тяжкий', 'вред', 'здоровье', 'по', 'признак', 'опасность'), 59)
# (('вред', 'здоровье', 'по', 'признак', 'опасность', 'для'), 59)
# (('здоровье', 'по', 'признак', 'опасность', 'для', 'жизнь'), 59)
# (('проезжий', 'часть', 'автодорога', 'при', 'движение', 'к'), 59)
# (('и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать'), 59)
# (('размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в'), 59)
# (('наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание'), 59)
# (('подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер'), 59)
# (('тяжкий', 'вред', 'здоровье', 'по', 'признак', 'опасность', 'для'), 59)
# (('вред', 'здоровье', 'по', 'признак', 'опасность', 'для', 'жизнь'), 59)
# (('вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать'), 59)
# (('и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в'), 59)
# (('размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание'), 59)
# (('наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер'), 59)
# (('подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и'), 59)
# (('тяжкий', 'вред', 'здоровье', 'по', 'признак', 'опасность', 'для', 'жизнь'), 59)
# (('определение', 'вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать'), 59)
# (('вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в'), 59)
# (('и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание'), 59)
# (('размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер'), 59)
# (('наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и'), 59)
# (('подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень'), 59)
# (('при', 'определение', 'вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать'), 59)
# (('определение', 'вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в'), 59)
# (('вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание'), 59)
# (('и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер'), 59)
# (('размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и'), 59)
# (('наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень'), 59)
# (('подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень', 'общественный'), 59)
# (('при', 'определение', 'вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в'), 59)
# (('определение', 'вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание'), 59)
# (('вид', 'и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер'), 59)
# (('и', 'размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и'), 59)
# (('размер', 'наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень'), 59)
# (('наказание', 'подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень', 'общественный'), 59)
# (('подсудимый', 'суд', 'принимать', 'в', 'внимание', 'характер', 'и', 'степень', 'общественный', 'опасность'), 59)
# (('материальный', 'ущерб', 'на'), 58)
# (('место', 'происшествие', 'от'), 58)
# (('конкретный', 'обстоятельство', 'дело'), 58)
# (('дополнительный', 'наказание', 'в'), 58)
# (('также', 'мнение', 'государственный'), 58)
# (('влияние', 'назначить', 'наказание'), 58)
# (('наказание', 'на', 'исправление'), 58)
# (('причинение', 'тяжкий', 'вред'), 58)
# (('осмотр', 'место', 'происшествие', 'от'), 58)
# (('дополнительный', 'наказание', 'в', 'вид'), 58)
# (('а', 'также', 'мнение', 'государственный'), 58)
# (('также', 'мнение', 'государственный', 'обвинитель'), 58)
# (('влияние', 'назначить', 'наказание', 'на'), 58)
# (('а', 'также', 'мнение', 'государственный', 'обвинитель'), 58)
# (('совершение', 'инкриминировать', 'он'), 57)
# (('ближний', 'свет', 'фара'), 57)
# (('защита', 'о', 'мера'), 57)
# (('в', 'совершение', 'инкриминировать', 'он'), 57)
# (('сторона', 'защита', 'о', 'мера'), 57)
# (('защита', 'о', 'мера', 'наказание'), 57)
# (('назначить', 'наказание', 'на', 'исправление'), 57)
# (('тайный', 'хищение', 'чужое', 'имущество', 'с'), 57)
# (('сторона', 'защита', 'о', 'мера', 'наказание'), 57)
# (('влияние', 'назначить', 'наказание', 'на', 'исправление'), 57)
# (('в', 'совершение', 'преступление'), 56)
# (('повлечь', 'по', 'неосторожность'), 56)
# (('согласно', 'протокол', 'осмотр'), 56)
# (('и', 'руководствоваться', 'ст'), 56)
# (('изложить', 'и', 'руководствоваться', 'ст'), 56)
# (('основание', 'изложить', 'и', 'руководствоваться', 'ст'), 56)
# (('здоровье', 'по', 'признак', 'опасность', 'для', 'жизнь', 'человек'), 56)
# (('вред', 'здоровье', 'по', 'признак', 'опасность', 'для', 'жизнь', 'человек'), 56)
# (('тяжкий', 'вред', 'здоровье', 'по', 'признак', 'опасность', 'для', 'жизнь', 'человек'), 56)
# (('инкриминировать', 'он', 'деяние'), 55)
# (('он', 'увидеть', 'что'), 55)
# (('о', 'утверждение', 'медицинский'), 55)
# (('утверждение', 'медицинский', 'критерий'), 55)
# (('обвиняться', 'в', 'совершение'), 55)
# (('материал', 'дело', 'установить'), 55)
# (('на', 'тайный', 'хищение'), 55)
# (('основание', 'для', 'применение'), 55)
# (('о', 'утверждение', 'медицинский', 'критерий'), 55)
# (('утверждение', 'медицинский', 'критерий', 'определение'), 55)
# (('на', 'правый', 'сторона', 'проезжий'), 55)
# (('причинение', 'тяжкий', 'вред', 'здоровье'), 55)
# (('протокол', 'осмотр', 'место', 'происшествие', 'от'), 55)
# (('о', 'утверждение', 'медицинский', 'критерий', 'определение'), 55)
# (('утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть'), 55)
# (('на', 'правый', 'сторона', 'проезжий', 'часть'), 55)
# (('о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть'), 55)
# (('утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред'), 55)
# (('на', 'основание', 'изложить', 'и', 'руководствоваться', 'ст'), 55)
# (('о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред'), 55)
# (('утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить'), 55)
# (('о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить'), 55)
# (('утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье'), 55)
# (('о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье'), 55)
# (('утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек'), 55)
# (('о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье', 'человек'), 55)
# (('передний', 'пассажирский', 'сидение'), 54)
# (('расположить', 'по', 'адрес'), 54)
# (('автомобиль', 'марка', 'ваза'), 54)
# (('незаконный', 'сбыт', 'наркотический'), 54)
# (('вина', 'в', 'совершение', 'инкриминировать'), 54)
# (('незаконный', 'сбыт', 'наркотический', 'средство'), 54)
# (('как', 'тяжкий', 'вред', 'здоровье', 'по', 'признак', 'опасность'), 54)
# (('как', 'тяжкий', 'вред', 'здоровье', 'по', 'признак', 'опасность', 'для'), 54)
# (('как', 'тяжкий', 'вред', 'здоровье', 'по', 'признак', 'опасность', 'для', 'жизнь'), 54)
# (('плата', 'р', 'и'), 53)
# (('р', 'и', 'год'), 53)
# (('и', 'год', 'о'), 53)
# (('год', 'о', 'в'), 53)
# (('о', 'в', 'о'), 53)
# (('в', 'о', 'р'), 53)
# (('о', 'р', 'и'), 53)
# (('р', 'и', 'литр'), 53)
# (('автодорога', 'по', 'направление'), 53)
# (('на', 'правый', 'обочина'), 53)
# (('обстоятельство', 'отягчать', 'наказание'), 53)
# (('73', 'ук', 'рф'), 53)
# (('признание', 'имя', 'свой'), 53)
# (('имя', 'свой', 'вина'), 53)
# (('плата', 'р', 'и', 'год'), 53)
# (('р', 'и', 'год', 'о'), 53)
# (('и', 'год', 'о', 'в'), 53)
# (('год', 'о', 'в', 'о'), 53)
# (('о', 'в', 'о', 'р'), 53)
# (('в', 'о', 'р', 'и'), 53)
# (('о', 'р', 'и', 'литр'), 53)
# (('совершение', 'инкриминировать', 'он', 'деяние'), 53)
# (('признание', 'имя', 'свой', 'вина'), 53)
# (('плата', 'р', 'и', 'год', 'о'), 53)
# (('р', 'и', 'год', 'о', 'в'), 53)
# (('и', 'год', 'о', 'в', 'о'), 53)
# (('год', 'о', 'в', 'о', 'р'), 53)
# (('о', 'в', 'о', 'р', 'и'), 53)
# (('в', 'о', 'р', 'и', 'литр'), 53)
# (('в', 'совершение', 'инкриминировать', 'он', 'деяние'), 53)
# (('плата', 'р', 'и', 'год', 'о', 'в'), 53)
# (('р', 'и', 'год', 'о', 'в', 'о'), 53)
# (('и', 'год', 'о', 'в', 'о', 'р'), 53)
# (('год', 'о', 'в', 'о', 'р', 'и'), 53)
# (('о', 'в', 'о', 'р', 'и', 'литр'), 53)
# (('плата', 'р', 'и', 'год', 'о', 'в', 'о'), 53)
# (('р', 'и', 'год', 'о', 'в', 'о', 'р'), 53)
# (('и', 'год', 'о', 'в', 'о', 'р', 'и'), 53)
# (('год', 'о', 'в', 'о', 'р', 'и', 'литр'), 53)
# (('плата', 'р', 'и', 'год', 'о', 'в', 'о', 'р'), 53)
# (('р', 'и', 'год', 'о', 'в', 'о', 'р', 'и'), 53)
# (('и', 'год', 'о', 'в', 'о', 'р', 'и', 'литр'), 53)
# (('плата', 'р', 'и', 'год', 'о', 'в', 'о', 'р', 'и'), 53)
# (('р', 'и', 'год', 'о', 'в', 'о', 'р', 'и', 'литр'), 53)
# (('плата', 'р', 'и', 'год', 'о', 'в', 'о', 'р', 'и', 'литр'), 53)
# (('по', 'неосторожность', 'смерть'), 52)
# (('на', 'проезжий', 'часть'), 52)
# (('на', 'передний', 'пассажирский'), 52)
# (('телесный', 'повреждение', 'который'), 52)
# (('через', 'некоторый', 'время'), 52)
# (('дело', 'установить', 'что'), 52)
# (('предъявить', 'он', 'обвинение'), 52)
# (('на', 'исправление', 'осудить'), 52)
# (('без', 'цель', 'сбыт'), 52)
# (('в', 'крупный', 'размер'), 52)
# (('материал', 'дело', 'установить', 'что'), 52)
# (('наказание', 'на', 'исправление', 'осудить'), 52)
# (('средство', 'в', 'сумма', 'рубль'), 52)
# (('назначить', 'наказание', 'на', 'исправление', 'осудить'), 52)
# (('денежный', 'средство', 'в', 'сумма', 'рубль'), 52)
# (('влияние', 'назначить', 'наказание', 'на', 'исправление', 'осудить'), 52)
# (('как', 'тяжкий', 'вред', 'здоровье', 'по', 'признак', 'опасность', 'для', 'жизнь', 'человек'), 52)
# (('на', 'сумма', 'рубль'), 51)
# (('связь', 'с', 'чем'), 51)
# (('в', 'содеять', 'раскаяться'), 51)
# (('о', 'личность', 'подсудимый'), 51)
# (('на', 'километр', 'автодорога'), 51)
# (('находиться', 'в', 'состояние'), 51)
# (('примерно', 'в', 'час'), 51)
# (('194н', 'о', 'утверждение'), 51)
# (('ст', '73', 'ук'), 51)
# (('раскаяние', 'в', 'содеять'), 51)
# (('для', 'применение', 'к'), 51)
# (('ход', 'предварительный', 'следствие'), 51)
# (('в', 'связь', 'с', 'чем'), 51)
# (('на', 'передний', 'пассажирский', 'сидение'), 51)
# (('194н', 'о', 'утверждение', 'медицинский'), 51)
# (('ст', '73', 'ук', 'рф'), 51)
# (('основание', 'для', 'применение', 'к'), 51)
# (('в', 'ход', 'предварительный', 'следствие'), 51)
# (('194н', 'о', 'утверждение', 'медицинский', 'критерий'), 51)
# (('194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение'), 51)
# (('194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть'), 51)
# (('194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред'), 51)
# (('194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить'), 51)
# (('194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить', 'здоровье'), 51)
# (('транспортный', 'средство', 'и'), 50)
# (('с', 'скорость', 'примерно'), 50)
# (('примерно', 'в', 'часы'), 50)
# (('увидеть', 'что', 'на'), 50)
# (('защитник', 'а', 'так'), 50)
# (('так', 'же', 'что'), 50)
# (('правый', 'обочина', 'автодорога'), 50)
# (('подсудимый', 'а', 'также'), 50)
# (('с', 'защитник', 'а', 'так'), 50)
# (('защитник', 'а', 'так', 'же'), 50)
# (('а', 'так', 'же', 'что'), 50)
# (('на', 'тайный', 'хищение', 'чужое'), 50)
# (('консультация', 'с', 'защитник', 'а', 'так'), 50)
# (('с', 'защитник', 'а', 'так', 'же'), 50)
# (('защитник', 'а', 'так', 'же', 'что'), 50)
# (('на', 'тайный', 'хищение', 'чужое', 'имущество'), 50)
# (('после', 'консультация', 'с', 'защитник', 'а', 'так'), 50)
# (('консультация', 'с', 'защитник', 'а', 'так', 'же'), 50)
# (('с', 'защитник', 'а', 'так', 'же', 'что'), 50)
# (('на', 'правый', 'сторона', 'проезжий', 'часть', 'автодорога'), 50)
# (('и', 'после', 'консультация', 'с', 'защитник', 'а', 'так'), 50)
# (('после', 'консультация', 'с', 'защитник', 'а', 'так', 'же'), 50)
# (('консультация', 'с', 'защитник', 'а', 'так', 'же', 'что'), 50)
# (('добровольно', 'и', 'после', 'консультация', 'с', 'защитник', 'а', 'так'), 50)
# (('и', 'после', 'консультация', 'с', 'защитник', 'а', 'так', 'же'), 50)
# (('после', 'консультация', 'с', 'защитник', 'а', 'так', 'же', 'что'), 50)
# (('добровольно', 'и', 'после', 'консультация', 'с', 'защитник', 'а', 'так', 'же'), 50)
# (('и', 'после', 'консультация', 'с', 'защитник', 'а', 'так', 'же', 'что'), 50)
# (('добровольно', 'и', 'после', 'консультация', 'с', 'защитник', 'а', 'так', 'же', 'что'), 50)
# (('чистосердечный', 'раскаяние', 'в'), 49)
# (('применение', 'к', 'подсудимый'), 49)
# (('автодорога', 'по', 'направление', 'к'), 49)
# (('чистосердечный', 'раскаяние', 'в', 'содеять'), 49)
# (('и', 'конкретный', 'обстоятельство'), 48)
# (('причинить', 'по', 'неосторожность'), 48)
# (('государственный', 'регистрационный', 'знак'), 48)
# (('к', 'обстоятельство', 'смягчающий'), 48)
# (('полностью', 'осознать', 'последствие'), 48)
# (('осознать', 'последствие', 'постановление'), 48)
# (('задний', 'габаритный', 'огонь'), 48)
# (('скрыться', 'и', 'распорядиться'), 48)
# (('смягчающий', 'наказание', 'подсудимый'), 48)
# (('полностью', 'осознать', 'последствие', 'постановление'), 48)
# (('осознать', 'последствие', 'постановление', 'приговор'), 48)
# (('полностью', 'осознать', 'последствие', 'постановление', 'приговор'), 48)
# (('осознать', 'последствие', 'постановление', 'приговор', 'без'), 48)
# (('полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без'), 48)
# (('осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение'), 48)
# (('полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение'), 48)
# (('осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 48)
# (('полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 48)
# (('осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 48)
# (('полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 48)
# (('преступление', 'сведение', 'о'), 47)
# (('изоляция', 'от', 'общество'), 47)
# (('в', 'который', 'находиться'), 47)
# (('рф', 'суд', 'приговорить'), 47)
# (('существенно', 'уменьшать', 'степень'), 47)
# (('уменьшать', 'степень', 'общественный'), 47)
# (('преступление', 'сведение', 'о', 'личность'), 47)
# (('и', 'конкретный', 'обстоятельство', 'дело'), 47)
# (('упк', 'рф', 'суд', 'приговорить'), 47)
# (('существенно', 'уменьшать', 'степень', 'общественный'), 47)
# (('уменьшать', 'степень', 'общественный', 'опасность'), 47)
# (('сторона', 'проезжий', 'часть', 'автодорога', 'при'), 47)
# (('существенно', 'уменьшать', 'степень', 'общественный', 'опасность'), 47)
# (('уменьшать', 'степень', 'общественный', 'опасность', 'совершенный'), 47)
# (('сторона', 'проезжий', 'часть', 'автодорога', 'при', 'движение'), 47)
# (('существенно', 'уменьшать', 'степень', 'общественный', 'опасность', 'совершенный'), 47)
# (('обстоятельство', 'смягчающий', 'он'), 46)
# (('год', '194н', 'о'), 46)
# (('водитель', 'автомобиль', 'марка'), 46)
# (('а', 'также', 'влияние'), 46)
# (('также', 'влияние', 'назначить'), 46)
# (('обстоятельство', 'существенно', 'уменьшать'), 46)
# (('2008', 'год', '194н', 'о'), 46)
# (('год', '194н', 'о', 'утверждение'), 46)
# (('а', 'также', 'влияние', 'назначить'), 46)
# (('также', 'влияние', 'назначить', 'наказание'), 46)
# (('для', 'применение', 'к', 'подсудимый'), 46)
# (('обстоятельство', 'существенно', 'уменьшать', 'степень'), 46)
# (('апрель', '2008', 'год', '194н', 'о'), 46)
# (('2008', 'год', '194н', 'о', 'утверждение'), 46)
# (('год', '194н', 'о', 'утверждение', 'медицинский'), 46)
# (('а', 'также', 'влияние', 'назначить', 'наказание'), 46)
# (('также', 'влияние', 'назначить', 'наказание', 'на'), 46)
# (('основание', 'для', 'применение', 'к', 'подсудимый'), 46)
# (('обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный'), 46)
# (('24', 'апрель', '2008', 'год', '194н', 'о'), 46)
# (('апрель', '2008', 'год', '194н', 'о', 'утверждение'), 46)
# (('2008', 'год', '194н', 'о', 'утверждение', 'медицинский'), 46)
# (('год', '194н', 'о', 'утверждение', 'медицинский', 'критерий'), 46)
# (('а', 'также', 'влияние', 'назначить', 'наказание', 'на'), 46)
# (('также', 'влияние', 'назначить', 'наказание', 'на', 'исправление'), 46)
# (('обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный', 'опасность'), 46)
# (('от', '24', 'апрель', '2008', 'год', '194н', 'о'), 46)
# (('24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение'), 46)
# (('апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский'), 46)
# (('2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий'), 46)
# (('год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение'), 46)
# (('сторона', 'проезжий', 'часть', 'автодорога', 'при', 'движение', 'к'), 46)
# (('а', 'также', 'влияние', 'назначить', 'наказание', 'на', 'исправление'), 46)
# (('также', 'влияние', 'назначить', 'наказание', 'на', 'исправление', 'осудить'), 46)
# (('обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный', 'опасность', 'совершенный'), 46)
# (('россия', 'от', '24', 'апрель', '2008', 'год', '194н', 'о'), 46)
# (('от', '24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение'), 46)
# (('24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский'), 46)
# (('апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий'), 46)
# (('2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение'), 46)
# (('год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть'), 46)
# (('а', 'также', 'влияние', 'назначить', 'наказание', 'на', 'исправление', 'осудить'), 46)
# (('минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год', '194н', 'о'), 46)
# (('россия', 'от', '24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение'), 46)
# (('от', '24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский'), 46)
# (('24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий'), 46)
# (('апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение'), 46)
# (('2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть'), 46)
# (('год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред'), 46)
# (('приказ', 'минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год', '194н', 'о'), 46)
# (('минздравсоцразвития', 'россия', 'от', '24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение'), 46)
# (('россия', 'от', '24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский'), 46)
# (('от', '24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий'), 46)
# (('24', 'апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение'), 46)
# (('апрель', '2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть'), 46)
# (('2008', 'год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред'), 46)
# (('год', '194н', 'о', 'утверждение', 'медицинский', 'критерий', 'определение', 'тяжесть', 'вред', 'причинить'), 46)
# (('имущество', 'с', 'незаконный'), 45)
# (('свой', 'усмотрение', 'причинить'), 45)
# (('в', 'отношение', 'он'), 45)
# (('считать', 'необходимый', 'назначить'), 45)
# (('выехать', 'на', 'полоса'), 45)
# (('чужое', 'имущество', 'с', 'незаконный'), 45)
# (('имущество', 'с', 'незаконный', 'проникновение'), 45)
# (('по', 'свой', 'усмотрение', 'причинить'), 45)
# (('сведение', 'о', 'личность', 'подсудимый'), 45)
# (('316', 'упк', 'рф', 'суд'), 45)
# (('обстоятельство', 'отягчать', 'наказание', 'подсудимый'), 45)
# (('хищение', 'чужое', 'имущество', 'с', 'незаконный'), 45)
# (('чужое', 'имущество', 'с', 'незаконный', 'проникновение'), 45)
# (('имущество', 'с', 'незаконный', 'проникновение', 'в'), 45)
# (('автодорога', 'при', 'движение', 'к', 'адрес'), 45)
# (('тайный', 'хищение', 'чужое', 'имущество', 'с', 'незаконный'), 45)
# (('хищение', 'чужое', 'имущество', 'с', 'незаконный', 'проникновение'), 45)
# (('чужое', 'имущество', 'с', 'незаконный', 'проникновение', 'в'), 45)
# (('тайный', 'хищение', 'чужое', 'имущество', 'с', 'незаконный', 'проникновение'), 45)
# (('хищение', 'чужое', 'имущество', 'с', 'незаконный', 'проникновение', 'в'), 45)
# (('тайный', 'хищение', 'чужое', 'имущество', 'с', 'незаконный', 'проникновение', 'в'), 45)
# (('откуда', 'тайно', 'похитить'), 44)
# (('суд', 'относить', 'к'), 44)
# (('относить', 'к', 'обстоятельство'), 44)
# (('рф', 'и', 'ходатайствовать'), 44)
# (('с', 'учёт', 'правило'), 44)
# (('в', 'это', 'время'), 44)
# (('по', 'уголовный', 'дело'), 44)
# (('а', 'также', 'обстоятельство'), 44)
# (('необходимый', 'назначить', 'подсудимый'), 44)
# (('суд', 'относить', 'к', 'обстоятельство'), 44)
# (('относить', 'к', 'обстоятельство', 'смягчающий'), 44)
# (('рф', 'и', 'ходатайствовать', 'о'), 44)
# (('обстоятельство', 'смягчающий', 'наказание', 'подсудимый'), 44)
# (('суд', 'относить', 'к', 'обстоятельство', 'смягчающий'), 44)
# (('рф', 'и', 'ходатайствовать', 'о', 'постановление'), 44)
# (('рф', 'и', 'ходатайствовать', 'о', 'постановление', 'приговор'), 44)
# (('рф', 'и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без'), 44)
# (('рф', 'и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение'), 44)
# (('рф', 'и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 44)
# (('рф', 'и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 44)
# (('заседание', 'следующий', 'он'), 43)
# (('опасность', 'для', 'движение'), 43)
# (('ходатайство', 'заявить', 'имя'), 43)
# (('заявить', 'имя', 'добровольно'), 43)
# (('имя', 'добровольно', 'и'), 43)
# (('после', 'тот', 'как'), 43)
# (('с', 'предъявить', 'он'), 43)
# (('омвд', 'россия', 'по'), 43)
# (('поскольку', 'исключительный', 'обстоятельство'), 43)
# (('исключительный', 'обстоятельство', 'существенно'), 43)
# (('преступление', 'по', 'дело'), 43)
# (('с', 'государственный', 'регистрационный'), 43)
# (('судебный', 'заседание', 'следующий', 'он'), 43)
# (('ук', 'рф', 'и', 'ходатайствовать'), 43)
# (('данный', 'ходатайство', 'заявить', 'имя'), 43)
# (('ходатайство', 'заявить', 'имя', 'добровольно'), 43)
# (('заявить', 'имя', 'добровольно', 'и'), 43)
# (('имя', 'добровольно', 'и', 'после'), 43)
# (('с', 'предъявить', 'он', 'обвинение'), 43)
# (('поскольку', 'исключительный', 'обстоятельство', 'существенно'), 43)
# (('исключительный', 'обстоятельство', 'существенно', 'уменьшать'), 43)
# (('преступление', 'по', 'дело', 'не'), 43)
# (('с', 'государственный', 'регистрационный', 'знак'), 43)
# (('в', 'судебный', 'заседание', 'следующий', 'он'), 43)
# (('ук', 'рф', 'и', 'ходатайствовать', 'о'), 43)
# (('данный', 'ходатайство', 'заявить', 'имя', 'добровольно'), 43)
# (('ходатайство', 'заявить', 'имя', 'добровольно', 'и'), 43)
# (('заявить', 'имя', 'добровольно', 'и', 'после'), 43)
# (('316', 'упк', 'рф', 'суд', 'приговорить'), 43)
# (('поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать'), 43)
# (('исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень'), 43)
# (('преступление', 'по', 'дело', 'не', 'установить'), 43)
# (('пояснить', 'в', 'судебный', 'заседание', 'следующий', 'он'), 43)
# (('ук', 'рф', 'и', 'ходатайствовать', 'о', 'постановление'), 43)
# (('данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и'), 43)
# (('ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после'), 43)
# (('поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень'), 43)
# (('исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный'), 43)
# (('ук', 'рф', 'и', 'ходатайствовать', 'о', 'постановление', 'приговор'), 43)
# (('данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после'), 43)
# (('поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный'), 43)
# (('исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный', 'опасность'), 43)
# (('ук', 'рф', 'и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без'), 43)
# (('поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный', 'опасность'), 43)
# (('исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный', 'опасность', 'совершенный'), 43)
# (('ук', 'рф', 'и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение'), 43)
# (('поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный', 'опасность', 'совершенный'), 43)
# (('ук', 'рф', 'и', 'ходатайствовать', 'о', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 43)
# (('незаконно', 'проникнуть', 'в'), 42)
# (('наезд', 'на', 'пешеход'), 42)
# (('также', 'обстоятельство', 'смягчающий'), 42)
# (('и', 'отягчать', 'наказание'), 42)
# (('чужое', 'имущество', 'группа'), 42)
# (('имущество', 'группа', 'лицо'), 42)
# (('не', 'находить', 'поскольку'), 42)
# (('находить', 'поскольку', 'исключительный'), 42)
# (('на', 'незаконный', 'сбыт'), 42)
# (('вещество', 'растительный', 'происхождение'), 42)
# (('согласие', 'с', 'предъявить', 'он'), 42)
# (('а', 'также', 'обстоятельство', 'смягчающий'), 42)
# (('смягчающий', 'и', 'отягчать', 'наказание'), 42)
# (('хищение', 'чужое', 'имущество', 'группа'), 42)
# (('чужое', 'имущество', 'группа', 'лицо'), 42)
# (('не', 'находить', 'поскольку', 'исключительный'), 42)
# (('находить', 'поскольку', 'исключительный', 'обстоятельство'), 42)
# (('согласие', 'с', 'предъявить', 'он', 'обвинение'), 42)
# (('обстоятельство', 'смягчающий', 'и', 'отягчать', 'наказание'), 42)
# (('хищение', 'чужое', 'имущество', 'группа', 'лицо'), 42)
# (('не', 'находить', 'поскольку', 'исключительный', 'обстоятельство'), 42)
# (('находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно'), 42)
# (('не', 'находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно'), 42)
# (('находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать'), 42)
# (('не', 'находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать'), 42)
# (('находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень'), 42)
# (('не', 'находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень'), 42)
# (('находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный'), 42)
# (('не', 'находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный'), 42)
# (('находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный', 'опасность'), 42)
# (('не', 'находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный', 'опасность'), 42)
# (('находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный', 'опасность', 'совершенный'), 42)
# (('число', '2', 'ст'), 41)
# (('двигаться', 'по', 'правый'), 41)
# (('что', 'он', 'полностью'), 41)
# (('он', 'полностью', 'осознать'), 41)
# (('относиться', 'к', 'категория'), 41)
# (('автомобиль', 'марка', 'рег'), 41)
# (('опасность', 'совершенный', 'имя'), 41)
# (('судебный', 'заседание', 'государственный'), 41)
# (('заседание', 'государственный', 'обвинитель'), 41)
# (('марка', 'с', 'государственный'), 41)
# (('ст.15', 'ук', 'рф'), 41)
# (('по', 'независящий', 'от'), 41)
# (('что', 'он', 'полностью', 'осознать'), 41)
# (('он', 'полностью', 'осознать', 'последствие'), 41)
# (('общественный', 'опасность', 'совершенный', 'имя'), 41)
# (('опасность', 'совершенный', 'имя', 'преступление'), 41)
# (('в', 'судебный', 'заседание', 'государственный'), 41)
# (('судебный', 'заседание', 'государственный', 'обвинитель'), 41)
# (('имущество', 'группа', 'лицо', 'по'), 41)
# (('суд', 'не', 'находить', 'поскольку'), 41)
# (('вина', 'в', 'совершение', 'инкриминировать', 'он'), 41)
# (('что', 'данный', 'ходатайство', 'заявить', 'имя'), 41)
# (('имя', 'добровольно', 'и', 'после', 'консультация'), 41)
# (('что', 'он', 'полностью', 'осознать', 'последствие'), 41)
# (('он', 'полностью', 'осознать', 'последствие', 'постановление'), 41)
# (('общественный', 'опасность', 'совершенный', 'имя', 'преступление'), 41)
# (('в', 'судебный', 'заседание', 'государственный', 'обвинитель'), 41)
# (('чужое', 'имущество', 'группа', 'лицо', 'по'), 41)
# (('имущество', 'группа', 'лицо', 'по', 'предварительный'), 41)
# (('суд', 'не', 'находить', 'поскольку', 'исключительный'), 41)
# (('заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя'), 41)
# (('что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно'), 41)
# (('заявить', 'имя', 'добровольно', 'и', 'после', 'консультация'), 41)
# (('имя', 'добровольно', 'и', 'после', 'консультация', 'с'), 41)
# (('что', 'он', 'полностью', 'осознать', 'последствие', 'постановление'), 41)
# (('он', 'полностью', 'осознать', 'последствие', 'постановление', 'приговор'), 41)
# (('хищение', 'чужое', 'имущество', 'группа', 'лицо', 'по'), 41)
# (('чужое', 'имущество', 'группа', 'лицо', 'по', 'предварительный'), 41)
# (('имущество', 'группа', 'лицо', 'по', 'предварительный', 'сговор'), 41)
# (('суд', 'не', 'находить', 'поскольку', 'исключительный', 'обстоятельство'), 41)
# (('дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя'), 41)
# (('заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно'), 41)
# (('что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и'), 41)
# (('ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация'), 41)
# (('заявить', 'имя', 'добровольно', 'и', 'после', 'консультация', 'с'), 41)
# (('имя', 'добровольно', 'и', 'после', 'консультация', 'с', 'защитник'), 41)
# (('что', 'он', 'полностью', 'осознать', 'последствие', 'постановление', 'приговор'), 41)
# (('он', 'полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без'), 41)
# (('хищение', 'чужое', 'имущество', 'группа', 'лицо', 'по', 'предварительный'), 41)
# (('чужое', 'имущество', 'группа', 'лицо', 'по', 'предварительный', 'сговор'), 41)
# (('суд', 'не', 'находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно'), 41)
# (('по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя'), 41)
# (('дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно'), 41)
# (('заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и'), 41)
# (('что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после'), 41)
# (('данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация'), 41)
# (('ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация', 'с'), 41)
# (('заявить', 'имя', 'добровольно', 'и', 'после', 'консультация', 'с', 'защитник'), 41)
# (('имя', 'добровольно', 'и', 'после', 'консультация', 'с', 'защитник', 'а'), 41)
# (('что', 'он', 'полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без'), 41)
# (('он', 'полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение'), 41)
# (('хищение', 'чужое', 'имущество', 'группа', 'лицо', 'по', 'предварительный', 'сговор'), 41)
# (('суд', 'не', 'находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать'), 41)
# (('разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя'), 41)
# (('по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно'), 41)
# (('дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и'), 41)
# (('заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после'), 41)
# (('что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация'), 41)
# (('данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация', 'с'), 41)
# (('ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация', 'с', 'защитник'), 41)
# (('заявить', 'имя', 'добровольно', 'и', 'после', 'консультация', 'с', 'защитник', 'а'), 41)
# (('что', 'он', 'полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение'), 41)
# (('он', 'полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 41)
# (('суд', 'не', 'находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень'), 41)
# (('судебный', 'разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя'), 41)
# (('разбирательство', 'по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно'), 41)
# (('по', 'дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и'), 41)
# (('дело', 'заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после'), 41)
# (('заявить', 'что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация'), 41)
# (('что', 'данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация', 'с'), 41)
# (('данный', 'ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация', 'с', 'защитник'), 41)
# (('ходатайство', 'заявить', 'имя', 'добровольно', 'и', 'после', 'консультация', 'с', 'защитник', 'а'), 41)
# (('что', 'он', 'полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение', 'судебный'), 41)
# (('он', 'полностью', 'осознать', 'последствие', 'постановление', 'приговор', 'без', 'проведение', 'судебный', 'разбирательство'), 41)
# (('суд', 'не', 'находить', 'поскольку', 'исключительный', 'обстоятельство', 'существенно', 'уменьшать', 'степень', 'общественный'), 41)
# (('он', 'деяние', 'признать'), 40)
# (('обочина', 'автодорога', 'при'), 40)
# (('технический', 'возможность', 'предотвратить'), 40)
# (('с', 'место', 'происшествие'), 40)
# (('без', 'цель', 'хищение'), 40)
# (('в', 'качество', 'понятой'), 40)
# (('ст', '316', 'упк'), 40)
# (('общий', 'сумма', 'рубль'), 40)
# (('автомобиль', 'марка', 'с'), 40)
# (('содержимый', 'наркотический', 'средство'), 40)
# (('дд.мм.гга', 'примерно', 'в'), 40)
# (('инкриминировать', 'он', 'деяние', 'признать'), 40)
# (('согласно', 'протокол', 'осмотр', 'место'), 40)
# (('обочина', 'автодорога', 'при', 'движение'), 40)
# (('ст', '316', 'упк', 'рф'), 40)
# (('также', 'обстоятельство', 'смягчающий', 'и'), 40)
# (('считать', 'необходимый', 'назначить', 'подсудимый'), 40)
# (('выехать', 'на', 'полоса', 'встречный'), 40)
# (('а', 'также', 'обстоятельство', 'смягчающий', 'и'), 40)
# (('также', 'обстоятельство', 'смягчающий', 'и', 'отягчать'), 40)
# (('выехать', 'на', 'полоса', 'встречный', 'движение'), 40)
# (('вина', 'в', 'совершение', 'инкриминировать', 'он', 'деяние'), 40)
# (('а', 'также', 'обстоятельство', 'смягчающий', 'и', 'отягчать'), 40)
# (('также', 'обстоятельство', 'смягчающий', 'и', 'отягчать', 'наказание'), 40)
# (('а', 'также', 'обстоятельство', 'смягчающий', 'и', 'отягчать', 'наказание'), 40)
# (('после', 'что', 'с'), 39)
# (('свобода', 'в', 'предел'), 39)
# (('расцениваться', 'как', 'тяжкий'), 39)
# (('что', 'суд', 'относить'), 39)
# (('особый', 'порядок', 'судебный'), 39)
# (('порядок', 'судебный', 'разбирательство'), 39)
# (('1', 'правило', 'дорожный'), 39)
# (('превышать', 'два', 'треть'), 39)
# (('два', 'треть', 'максимальный'), 39)

# %%
colloc_1000[:10]
# Out:
# ['в судебный заседание',
#  'без проведение судебный',
#  'проведение судебный разбирательство',
#  'без проведение судебный разбирательство',
#  'приговор без проведение',
#  'приговор без проведение судебный',
#  'приговор без проведение судебный разбирательство',
#  'хищение чужое имущество',
#  'правило дорожный движение',
#  'проезжий часть автодорога']

# %%
tfidf = TfidfVectorizer(ngram_range=(3,10), min_df=40)

# %%
df['tokens_str'] = [' '.join(i) for i in df.norm_main_parts]

# %%
texts_vectors = tfidf.fit_transform(df['tokens_str'])

# %%
texts_vectors
# Out:
# <115x366 sparse matrix of type '<class 'numpy.float64'>'
# 	with 20103 stored elements in Compressed Sparse Row format>

# %%
id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}

# %%
df['tf-idf'] = pd.Series()

# %%
df.head()
# Out:
#                                       raw_main_parts  \
# 0   Стульников С.В. совершил кражу, т.е. тайное х...
# 1   Крутилин С.В., являясь лицом, управляющим авт...
# 2   Видюлин П.А. обвиняется в совершении неправом...
# 3   Кузнецов М.Ю. совершил нарушение лицом, управ...
# 4   Кочетков Д.Г. совершил нарушение лицом, управ...
#
#                                      norm_main_parts  \
# 0  [стульник, с.в, совершить, кража, т.е, тайный,...
# 1  [крутилина, с.в, являться, лицо, управлять, ав...
# 2  [видюлина, п.а, обвиняться, в, совершение, неп...
# 3  [кузнецов, м.ю, совершить, нарушение, лицо, уп...
# 4  [кочетков, д.г, совершить, нарушение, лицо, уп...
#
#                                           tokens_str  tf-idf
# 0  стульник с.в совершить кража т.е тайный хищени...     NaN
# 1  крутилина с.в являться лицо управлять автомоби...     NaN
# 2  видюлина п.а обвиняться в совершение неправоме...     NaN
# 3  кузнецов м.ю совершить нарушение лицо управлят...     NaN
# 4  кочетков д.г совершить нарушение лицо управлят...     NaN

# %%
some_array = []
for i in range(len(df.tokens_str)):
    some_dict = {}
    for num, s in enumerate(texts_vectors.toarray()[i]):
        some_dict.setdefault((id2word[num]), s)
    sorted_dict = OrderedDict(sorted(some_dict.items(), key=lambda t: t[1])[::-1])    # сортировка значений по убыванию
    minim_array = [[item[0] for item in sorted_dict.items() if item[1]!=0]]
    df.iloc[i, 3] = minim_array
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-08e6f68e0859> in <module>
#       6     sorted_dict = OrderedDict(sorted(some_dict.items(), key=lambda t: t[1])[::-1])    # сортировка значений по убыванию
#       7     minim_array = [[item[0] for item in sorted_dict.items() if item[1]!=0]]
# ----> 8     df.iloc[i, 3] = minim_array
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
#     188         indexer = self._get_setitem_indexer(key)
# --> 189         self._setitem_with_indexer(indexer, value)
#     190
#     191     def _validate_key(self, key, axis):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     588                     value = np.array(value, dtype=object)
#     589                     if len(labels) != value.shape[1]:
# --> 590                         raise ValueError('Must have equal len keys and value '
#     591                                          'when setting with an ndarray')
#     592
#
# ValueError: Must have equal len keys and value when setting with an ndarray

# %%
df.head()

# %%
df['jur'] = pd.Series()
for num, item in enumerate(df['tf-idf']):
    print(item)
    for i in item:
        df.iloc[num, 4] = set(colloc_1000)&set(i)
